# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
main=pd.read_excel("finalhealthproj.xlsx")
main
# Out:
#     S.No      CNAME  Phone_No CLF_of_MEDS  Priority Address  MOP
# 0      1  Pravalika     345.0         ADR         1     CVB   CH
# 1      2     Govind     980.0         ANT         2     XYZ   CD
# 2      3   Subadhra     978.0         ANA         3     AER   OP
# 3      4      Satya     967.0         ANB         4     HYD   NB
# 4      5      Alexa     876.0         ANP         5     HFG   CD
# ..   ...        ...       ...         ...       ...     ...  ...
# 95    96     Sukuna       NaN         ANA         3     HYD  NaN
# 96    97   Bastilla       NaN         ADR         1     LOT  NaN
# 97    98   Brigette       NaN         ADR         1     LDK  NaN
# 98    99     Sultan       NaN         ANA         3     GTY  NaN
# 99   100      Akbar       NaN         ANP         5     HYD  NaN
#
# [100 rows x 7 columns]

# %%
mainf=main.drop(['S.No','Phone_No','Address','MOP'],axis=1)
mainf
# Out:
#         CNAME CLF_of_MEDS  Priority
# 0   Pravalika         ADR         1
# 1      Govind         ANT         2
# 2    Subadhra         ANA         3
# 3       Satya         ANB         4
# 4       Alexa         ANP         5
# ..        ...         ...       ...
# 95     Sukuna         ANA         3
# 96   Bastilla         ADR         1
# 97   Brigette         ADR         1
# 98     Sultan         ANA         3
# 99      Akbar         ANP         5
#
# [100 rows x 3 columns]

# %%
plt.scatter(mainf.CLF_of_MEDS,mainf.Priority,marker='*',color='purple')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
mainf["CLF_of_MEDS"]=le.fit_transform(mainf["CLF_of_MEDS"])
mainf
# Out:
#         CNAME  CLF_of_MEDS  Priority
# 0   Pravalika            0         1
# 1      Govind            4         2
# 2    Subadhra            1         3
# 3       Satya            2         4
# 4       Alexa            3         5
# ..        ...          ...       ...
# 95     Sukuna            1         3
# 96   Bastilla            0         1
# 97   Brigette            0         1
# 98     Sultan            1         3
# 99      Akbar            3         5
#
# [100 rows x 3 columns]

# %%
# adr=0,p=1   ant=4,p=2     ana=1,p=3      anb=2,p=4      anp=3,p=5

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(mainf[['CLF_of_MEDS']],mainf.Priority,train_size=0.4)

# %%
X_train
# Out:
#     CLF_of_MEDS
# 63            1
# 55            3
# 99            3
# 40            0
# 74            1
# 45            0
# 97            0
# 53            1
# 17            4
# 51            3
# 87            0
# 9             1
# 6             2
# 0             0
# 3             2
# 61            3
# 98            1
# 59            3
# 56            4
# 20            4
# 27            3
# 57            3
# 22            1
# 14            3
# 42            2
# 29            2
# 68            2
# 5             1
# 31            4
# 13            3
# 47            2
# 26            1
# 70            0
# 89            0
# 66            1
# 62            0
# 24            3
# 2             1
# 72            0
# 50            0

# %%
X_test
# Out:
#     CLF_of_MEDS
# 46            4
# 54            4
# 60            1
# 38            4
# 49            1
# 41            1
# 75            4
# 28            0
# 64            1
# 12            2
# 21            2
# 76            4
# 92            1
# 69            3
# 15            3
# 32            4
# 78            4
# 1             4
# 80            2
# 96            0
# 94            0
# 30            0
# 35            1
# 52            3
# 4             3
# 37            3
# 23            0
# 91            4
# 11            3
# 19            3
# 58            4
# 95            1
# 71            2
# 93            3
# 88            4
# 65            4
# 43            3
# 44            3
# 48            4
# 16            2
# 77            2
# 67            0
# 39            3
# 34            0
# 82            1
# 7             4
# 10            0
# 79            0
# 33            3
# 8             0
# 90            0
# 73            2
# 85            0
# 25            2
# ...

# %%
Y_train
# Out:
# 63    3
# 55    5
# 99    5
# 40    1
# 74    3
# 45    1
# 97    1
# 53    3
# 17    2
# 51    5
# 87    1
# 9     3
# 6     4
# 0     1
# 3     4
# 61    5
# 98    3
# 59    5
# 56    2
# 20    2
# 27    5
# 57    5
# 22    3
# 14    5
# 42    4
# 29    4
# 68    4
# 5     3
# 31    2
# 13    5
# 47    4
# 26    3
# 70    1
# 89    1
# 66    3
# 62    1
# 24    5
# 2     3
# 72    1
# 50    1
# Name: Priority, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([2, 2, 3, 2, 3, 3, 2, 1, 3, 3, 3, 2, 3, 5, 5, 2, 2, 2, 3, 1, 1, 1,
#        3, 5, 5, 5, 1, 2, 5, 5, 2, 3, 3, 5, 2, 2, 5, 5, 2, 3, 3, 1, 5, 1,
#        3, 2, 1, 1, 5, 1, 1, 3, 1, 3, 2, 1, 2, 3, 3, 3], dtype=int64)

# %%
model.predict(Y_test)
# Out:
# D:\AnacondaPY\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 model.predict(Y_test)
#
# File D:\AnacondaPY\Lib\site-packages\sklearn\linear_model\_base.py:451, in LinearClassifierMixin.predict(self, X)
#     437 """
#     438 Predict class labels for samples in X.
#     439
#    (...)
#     448     Vector containing the class labels for each sample.
#     449 """
#     450 xp, _ = get_namespace(X)
# --> 451 scores = self.decision_function(X)
#     452 if len(scores.shape) == 1:
#     453     indices = xp.astype(scores > 0, int)
#
# File D:\AnacondaPY\Lib\site-packages\sklearn\linear_model\_base.py:432, in LinearClassifierMixin.decision_function(self, X)
#     429 check_is_fitted(self)
# ...
